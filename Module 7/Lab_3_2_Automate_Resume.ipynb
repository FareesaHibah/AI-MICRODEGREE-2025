# %% [markdown]
# Analyze resumes determine the important skills present in the resumes.

# %%
pip install pandas nltk requests
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# Step 1: Importing necessary libraries

# %%
import pandas as pd

# %%
df = pd.read_csv('Resume.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2484 entries, 0 to 2483
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           2484 non-null   int64
#  1   Resume_str   2484 non-null   object
#  2   Resume_html  2484 non-null   object
#  3   Category     2484 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 77.8+ KB

# %%
df.head()
# Out:
#          ID                                         Resume_str  \
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1  22323967           HR SPECIALIST, US HR OPERATIONS      ...
# 2  33176873           HR DIRECTOR       Summary      Over 2...
# 3  27018550           HR SPECIALIST       Summary    Dedica...
# 4  17812897           HR MANAGER         Skill Highlights  ...
#
#                                          Resume_html Category
# 0  <div class="fontsize fontface vmargins hmargin...       HR
# 1  <div class="fontsize fontface vmargins hmargin...       HR
# 2  <div class="fontsize fontface vmargins hmargin...       HR
# 3  <div class="fontsize fontface vmargins hmargin...       HR
# 4  <div class="fontsize fontface vmargins hmargin...       HR

# %% [markdown]
# Step 3: Named Entity Recognization

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
from nltk import word_tokenize, pos_tag, ne_chunk
from nltk.tree import Tree
import re
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
def extract_named_entities(text):
  entities = {'PERSON': [], 'ORGANIZATION': [], 'GPE': []}
  chunk = ne_chunk(pos_tag(word_tokenize(text)))
  for x in chunk:
    if isinstance(x, Tree):
      Label = x.label()
      Entity = ''.join(y for y, _ in x.leaves())
      if Label in entities:
        entities[Label].append(Entity)
  return entities

# %% [markdown]
# Step 4: Skills Extracting Function

# %%
common_skills = set(['Python', 'Java', 'SQL', 'Excel', 'Leadership', 'Communication'])

def extract_skills(text):
  token = set(word_tokenize(text))
  return list(common_skills.intersection(token))

# %% [markdown]
# Step 5: Process Sample Resume

# %%
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
sample_resume = df['Resume_str'].iloc[2]
ner = extract_named_entities(sample_resume)
ner
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# {'PERSON': ['BenefitAdministrationPolicy',
#   'KansasHealthInstitute',
#   'Kansas',
#   'HonorRoll',
#   'Dean',
#   'HonorRoll',
#   'StudentLiaison',
#   'KansasTravel',
#   'Tourism',
#   'Change',
#   'HumanResourceCoordinator',
#   'ExperienceHR',
#   'CurrentCompanyNameCity',
#   'Agency',
#   'Developed',
#   'Oversaw',
#   'State',
#   'Ramp',
#   'Payroll',
#   'QualityControl',
#   'AgencyStaffing',
#   'PersonOffice',
#   'WorkComp',
#   'Benefits',
#   'State',
#   'State',
#   'HonorsTopeka',
#   'KansasHospital',
#   'CareHuman',
#   'LiaisonSkillsDesktopPublishing',
#   'AgencyAutomation',
#   'Benefits',
#   'CorelSuite',
#   'HarvardGraphics',
#   'Excel',
#   'MicrosoftPublisher',
#   'QuarkExpress',
#   'QuattroPro',
#   'StrategicPlanning'],
#  'ORGANIZATION': ['Human',
#   'HRIS',
#   'HealthcareEnviromentSkills',
#   'ManagementInstitute',
#   'SHRM',
#   'Commerce',
#   'FriendsUniversityTopeka',
#   'Topeka',
#   'ADDYAwards',
#   'ASHHRA',
#   'KAHHR',
#   'ACM',
#   'Adjutant',
#   'Retention',
#   'Adjutant',
#   'Federal',
#   'JointForcesHeadquarters',
#   'Federal',
#   'LMIS',
#   'JobVacancyProject',
#   'JVC',
#   'FTE',
#   'PRN',
#   'StateDevelopedNewWebsite',
#   'HRISSystem',
#   'EmployeeHandbook',
#   'StateDevelped',
#   'SHROWebsite',
#   'SHRO',
#   'Automation',
#   'Adjutant',
#   'TAG',
#   'KAPE',
#   'FireDepartment',
#   'HRIS',
#   'Met',
#   'SeniorManagement',
#   'HumanResources',
#   'StateDeveloped',
#   'HR',
#   'TrainingMaster',
#   'Commerce',
#   'Newsletter',
#   'DATABASEManagement',
#   'LeadershipTraining',
#   'OSHA',
#   'FMLA',
#   'WorkersCompensation'],
#  'GPE': ['Reviewed',
#   'UnitedStates',
#   'Science',
#   'UnitedStates',
#   'Budget',
#   'Access']}

# %%
skills = extract_skills(sample_resume)
skills
# Out:
# ['Excel', 'Leadership']

# %%
category = df['Category'].iloc[2]
category
# Out:
# 'HR'

# %% [markdown]
# Step 6: Applying first 10 rows

# %%
result = []
for i, j in df.head(10).iterrows():
  text = j['Resume_str']
  ner = extract_named_entities(text)
  skills = extract_skills(text)
  result.append({'ID': j['ID'],
                 'Category': j['Category'],
                 'Skills': skills,
                 'Entities': ner})
  result_df = pd.DataFrame(result)

# %%
result
# Out:
# [{'ID': 16852973,
#   'Category': 'HR',
#   'Skills': ['Leadership'],
#   'Entities': {'PERSON': ['Client',
#     'AccomplishmentsMissouri',
#     'ManagerTraining',
#     'HiltonOnQ',
#     'MicrosOperaPMS',
#     'FidelioOPERA',
#     'HolidexCompleted',
#     'ExperienceHR',
#     'CurrentCompanyName',
#     'AdvancedMedicalClaimsAnalystMar',
#     'ManagerJun',
#     'Hired',
#     'ExecutiveSupport',
#     'State',
#     'Marketing',
#     'FrontOfficeManager',
#     'PartnerDec',
#     'Business',
#     'JeffersonCollege',
#     'SchoolDiploma',
#     'CollegePrep',
#     'State',
#     'JeffersonCollegeSkillsAccounting',
#     'Marketing'],
#    'ORGANIZATION': ['ASSOCIATE',
#     'CustomerServiceManagement',
#     'IHG',
#     'SegmentHilton',
#     'ORS',
#     'StateHelps',
#     'Administers',
#     'StateReviewed',
#     'CPT',
#     'State',
#     'Commerce',
#     'CustomerService',
#     'HumanResources',
#     'State',
#     'State',
#     'StateEducation',
#     'StateBusinessAdministration',
#     'AmericanShrubelLeadership',
#     'CustomerService',
#     'HumanResources'],
#    'GPE': ['Hospitality', 'Customer', 'Facebook', 'Executive']}},
#  {'ID': 22323967,
#   'Category': 'HR',
#   'Skills': ['Communication'],
#   'Entities': {'PERSON': ['Marketing',
#     'CurrentHRSpecialist',
#     'Audited',
#     'DrugScreen',
#     'Marketing',
#     'State',
#     'MarketingToolkit',
#     'ExecutiveTradeshowsCalendar',
#     'Ordered',
#     'TellerCompanyName',
#     'State',
#     'State',
#     'AssetManagement',
#     'CustomerCare',
#     'FinalCutPro',
#     'LotusNotes',
#     'MicrosoftOffice',
#     'ProjectManagement',
#     'EmployeeDevelopment'],
#    'ORGANIZATION': ['US',
#     'Communications',
#     'HumanResources',
#     'Technology',
#     'US',
#     'StateManaged',
#     'Operations',
#     'HRManagers',
#     'US',
#     'BusinessUnit',
#     'BackgroundCheck',
#     'Communications',
#     'SharePoint',
#     'Communication',
#     'DigitalAsset',
#     'MySikorsky',
#     'StatePartnered',
#     'ATM',
#     'SeniorProducer',
#     'SHUMediaExchangeCompanyName',
#     'CorporateCommunication',
#     'PublicRelationsSacredHeartUniversity',
#     'CommunicationWesternConnecticut',
#     'University',
#     'StateSkillsAdobePhotoshop',
#     'ADP',
#     'HR',
#     'InDesign',
#     'SharePoint',
#     'RFP'],
#    'GPE': ['Audited', 'Illustrator', 'Innovation', 'Quality', 'Recruitment']}},
#  {'ID': 33176873,
#   'Category': 'HR',
#   'Skills': ['Excel', 'Leadership'],
#   'Entities': {'PERSON': ['BenefitAdministrationPolicy',
#     'KansasHealthInstitute',
#     'Kansas',
#     'HonorRoll',
#     'Dean',
#     'HonorRoll',
#     'StudentLiaison',
#     'KansasTravel',
#     'Tourism',
#     'Change',
#     'HumanResourceCoordinator',
#     'ExperienceHR',
#     'CurrentCompanyNameCity',
#     'Agency',
#     'Developed',
#     'Oversaw',
#     'State',
#     'Ramp',
#     'Payroll',
#     'QualityControl',
#     'AgencyStaffing',
#     'PersonOffice',
#     'WorkComp',
#     'Benefits',
#     'State',
#     'State',
#     'HonorsTopeka',
#     'KansasHospital',
#     'CareHuman',
#     'LiaisonSkillsDesktopPublishing',
#     'AgencyAutomation',
#     'Benefits',
#     'CorelSuite',
#     'HarvardGraphics',
#     'Excel',
#     'MicrosoftPublisher',
#     'QuarkExpress',
#     'QuattroPro',
#     'StrategicPlanning'],
#    'ORGANIZATION': ['Human',
#     'HRIS',
#     'HealthcareEnviromentSkills',
#     'ManagementInstitute',
#     'SHRM',
#     'Commerce',
#     'FriendsUniversityTopeka',
#     'Topeka',
#     'ADDYAwards',
#     'ASHHRA',
#     'KAHHR',
#     'ACM',
#     'Adjutant',
#     'Retention',
#     'Adjutant',
#     'Federal',
#     'JointForcesHeadquarters',
#     'Federal',
#     'LMIS',
#     'JobVacancyProject',
#     'JVC',
#     'FTE',
#     'PRN',
#     'StateDevelopedNewWebsite',
#     'HRISSystem',
#     'EmployeeHandbook',
#     'StateDevelped',
#     'SHROWebsite',
#     'SHRO',
#     'Automation',
#     'Adjutant',
#     'TAG',
#     'KAPE',
#     'FireDepartment',
#     'HRIS',
#     'Met',
#     'SeniorManagement',
#     'HumanResources',
#     'StateDeveloped',
#     'HR',
#     'TrainingMaster',
#     'Commerce',
#     'Newsletter',
#     'DATABASEManagement',
#     'LeadershipTraining',
#     'OSHA',
#     'FMLA',
#     'WorkersCompensation'],
#    'GPE': ['Reviewed',
#     'UnitedStates',
#     'Science',
#     'UnitedStates',
#     'Budget',
#     'Access']}},
#  {'ID': 27018550,
#   'Category': 'HR',
#   'Skills': ['Excel'],
#   'Entities': {'PERSON': ['Dynamic',
#     'Solid',
#     'SkillsType',
#     'Excel',
#     'Outlook',
#     'Inbound',
#     'ExperienceHrSpecialist',
#     'CustomerService',
#     'State',
#     'Developed',
#     'ShortTermDisability',
#     'CallCentreShiftSupervisor',
#     'MicrosoftExcel',
#     'MicrosoftOutlook',
#     'MicrosoftPowerPoint',
#     'MicrosoftWord'],
#    'ORGANIZATION': ['Microsoft',
#     'PowerPointPersonnel',
#     'Telephone',
#     'StateAccenturePeoplelineEmailManagementTeam',
#     'FMLA',
#     'AbsenceManagementTeam',
#     'StateAnswered',
#     'Dispatched',
#     'Medical',
#     'SanAntonio',
#     'TrainingCertificate',
#     'Completion',
#     'StateSkills',
#     'Type'],
#    'GPE': ['Driven', 'Access', 'Outbound', 'Call', 'Access']}},
#  {'ID': 17812897,
#   'Category': 'HR',
#   'Skills': ['Excel'],
#   'Entities': {'PERSON': ['SkillHighlightsHR',
#     'AdvocacyHRPolicies',
#     'RetentionSalaryNegotiationsEmployeeRelationsBenefits',
#     'Lawson',
#     'Paychex',
#     'Excel',
#     'Publisher',
#     'Visio',
#     'CurrentCompanyName',
#     'Ensure',
#     'ImplementHR',
#     'Identify',
#     'Develop',
#     'Recruit',
#     'Employee',
#     'Strategic',
#     'Black',
#     'Christmas',
#     'InfluenceHR',
#     'Ensure',
#     'Maintain',
#     'Ensure',
#     'ImproveHR',
#     'Structured',
#     'Wrote',
#     'Developed',
#     'EducationBachelor',
#     'HumanResourceManagement',
#     'MuskingumValleyHumanResource',
#     'SkillsADA',
#     'BenefitsAdministration',
#     'Coach',
#     'EmployeeRelations',
#     'HumanResource',
#     'Lawson',
#     'Law',
#     'Director',
#     'Excel',
#     'Outlook',
#     'Publisher',
#     'Word',
#     'PerformanceManagement',
#     'ProjectManagement',
#     'Strategic',
#     'Structured',
#     'Visio'],
#    'ORGANIZATION': ['SKILLS',
#     'Procedures',
#     'CompensationAdministrationOrientation',
#     'HRISTechnologies',
#     'DevelopmentPerformanceManagementOrganizational',
#     'ADP',
#     'Word',
#     'PowerPoint',
#     'State',
#     'HumanResource',
#     'VSTD',
#     'VLTD',
#     'HR',
#     'Corporate',
#     'HR',
#     'HR',
#     'HR',
#     'HR',
#     'Corporate',
#     'HR',
#     'HR',
#     'HR',
#     'HR',
#     'CEO',
#     'COO',
#     'CFO',
#     'CMO',
#     'FMLA',
#     'Board',
#     'Introduced',
#     'StateNation',
#     'HRGeneralist',
#     'BusinessAdministration',
#     'VERNON',
#     'NAZARENE',
#     'UNIVERSITY',
#     'State',
#     'SHRM',
#     'ADP',
#     'HRIS',
#     'HumanResources',
#     'HR',
#     'Mediation',
#     'PowerPoint',
#     'OrganizationalDevelopment'],
#    'GPE': ['Kronos',
#     'Access',
#     'Outlook',
#     'Health',
#     'Dental',
#     'Vision',
#     'Operations',
#     'Physicians',
#     'Hiring',
#     'Kronos',
#     'Access',
#     'Negotiations',
#     'Peak',
#     'Profit',
#     'Recruitment',
#     'Vision']}},
#  {'ID': 11592605,
#   'Category': 'HR',
#   'Skills': ['Excel'],
#   'Entities': {'PERSON': ['AdministrativeAssistant',
#     'HighlightsMicrosoft',
#     'Excel',
#     'Reduced',
#     'Developed',
#     'PsychologyEssexCountyCollege',
#     'StrategicPlanning',
#     'AnnualPerformanceEvaluation',
#     'Lisa',
#     'AnnualPerformanceEvaluation',
#     'MeritProposal',
#     'AnnualPerformanceEvaluationNotification',
#     'AnnualPerformanceEvaluation',
#     'Skills',
#     'HumanResourceManagement',
#     'Excel',
#     'MicrosoftOffice',
#     'Outlook',
#     'Word',
#     'PerformanceManagement',
#     'StrategicPlanning',
#     'Visio'],
#    'ORGANIZATION': ['GENERALIST',
#     'Meticulous',
#     'StateManaged',
#     'USCIS',
#     'USCIS',
#     'USCIS',
#     'USDHS',
#     'USDOS',
#     'HR',
#     'State',
#     'DesignatedSchool',
#     'AlternateResponsible',
#     'Assisted',
#     'AdministrativeAssistant',
#     'StateDrafted',
#     'PowerPoint',
#     'ABAApprovedParalegalProgram',
#     'JusticeStudiesMontclair',
#     'University',
#     'State',
#     'StatePsychologyCertificate',
#     'SHRMEssentials',
#     'HumanResourceManagement',
#     'Analysis',
#     'Selection',
#     'CompetenciesNewYorkInstitute',
#     'Technology',
#     'Department',
#     'ExchangeVisitorPrograms',
#     'ImmigrationServices',
#     'DesignatedSchool',
#     'NationalAssociation',
#     'ForeignStudentAdvisors',
#     'NAFSA',
#     'InternationalStudents',
#     'NJIT',
#     'OverallPerformance',
#     'NJIT',
#     'NJIT',
#     'OverallPerformanceLevel',
#     'NJIT',
#     'OverallPerformanceLevel',
#     'AdministrativeAssistant',
#     'HR',
#     'HumanResourcesManagement',
#     'PowerPoint'],
#    'GPE': ['Created',
#     'Critical',
#     'UnitedStates',
#     'Exchange',
#     'Office',
#     'Paralegal',
#     'Publications',
#     'Recruitment',
#     'Supervisor',
#     'Website']}},
#  {'ID': 25824789,
#   'Category': 'HR',
#   'Skills': ['Leadership'],
#   'Entities': {'PERSON': ['State',
#     'HighlightsUniversity',
#     'Advocacy',
#     'EmployeeRelationsWeb',
#     'SharepointHR',
#     'MicrosoftOfficeSuites',
#     'StaffDevelopment',
#     'Developed',
#     'State',
#     'ExperienceHR',
#     'CurrentCompanyNameCity',
#     'Work',
#     'Perform',
#     'StaffAwards',
#     'HumanResources',
#     'Sharepoint',
#     'State',
#     'LeadershipDevelopmentTraining',
#     'RestaurantManager',
#     'EducationBachelor',
#     'HumanResourceManagement',
#     'NorthTexasSociety',
#     'HumanResourceManagement',
#     'TexasHigher',
#     'DentonHighSchoolGirlsSoftball',
#     'SkillsADA',
#     'EmployeeRelations',
#     'Director',
#     'MicrosoftOfficeSuites',
#     'Publisher',
#     'Sharepoint',
#     'PerformanceManagement',
#     'ProjectManagement',
#     'Quark',
#     'Teacher',
#     'WebDesign'],
#    'ORGANIZATION': ['HR',
#     'HR',
#     'HRISTechnologies',
#     'TESOLTeacher',
#     'University',
#     'RedDot',
#     'DevelopmentPerformanceManagementOrganizational',
#     'Procedures',
#     'TWU',
#     'THEHRA',
#     'TWUHouston',
#     'TWU',
#     'StatePerform',
#     'University',
#     'Human',
#     'University',
#     'TESOL',
#     'CoordinateServiceAwards',
#     'Retirement',
#     'RedDot',
#     'Associate',
#     'HR',
#     'PeopleSoftTime',
#     'Labor',
#     'FMLA',
#     'HR',
#     'PeopleSoft',
#     'StateResponsible',
#     'TEXAS',
#     'UNIVERSITYCity',
#     'StateSociologyAffiliationsSociety',
#     'SHRM',
#     'NTSHRM',
#     'HumanResourcesAssociation',
#     'International',
#     'TESOL',
#     'ADMINISTRATIVE',
#     'SpecialEvents',
#     'HRIS',
#     'HumanResources',
#     'HR',
#     'InDesign',
#     'LeadershipDevelopment',
#     'Mediation',
#     'OrganizationalDevelopment',
#     'PeopleSoft'],
#    'GPE': ['English',
#     'New',
#     'New',
#     'Spanish',
#     'Spanish',
#     'Science',
#     'English',
#     'Newsletters',
#     'Policies',
#     'Spanish',
#     'Teaching']}},
#  {'ID': 15375009,
#   'Category': 'HR',
#   'Skills': [],
#   'Entities': {'PERSON': ['DrivenHRManager',
#     'CreativeBusinessPartner',
#     'Skills',
#     'Benefits',
#     'CurrentCompanyName',
#     'Cut',
#     'Achieved',
#     'BenefitsBroker',
#     'Developed',
#     'Developed',
#     'Developed',
#     'Developed',
#     'BenefitsAdministrator',
#     'Developed',
#     'Developed',
#     'Reviewed',
#     'Developed',
#     'Developed',
#     'Reviewed',
#     'Reviewed',
#     'EducationBachelor',
#     'BusinessManagement',
#     'Center',
#     'NamurUniversity'],
#    'ORGANIZATION': ['ADP',
#     'HR',
#     'StateDeveloped',
#     'StateActed',
#     'State',
#     'HumanResourcesSupervisor',
#     'State',
#     'HumanResources',
#     'State',
#     'COBRA',
#     'FMLA',
#     'HumanResourcesAssistant',
#     'State',
#     'University',
#     'StateBusinessManagement',
#     'University',
#     'State',
#     'StateHumanResources'],
#    'GPE': ['Team',
#     'Payroll',
#     'Project',
#     'Science',
#     'Phoenix',
#     'San',
#     'City',
#     'Phoenix',
#     'City',
#     'City']}},
#  {'ID': 11847784,
#   'Category': 'HR',
#   'Skills': ['Excel'],
#   'Entities': {'PERSON': ['Managed',
#     'Ensured',
#     'Developed',
#     'SkillsManagement',
#     'Excel',
#     'Ensure',
#     'Develop',
#     'Develop',
#     'State',
#     'Ensured',
#     'State',
#     'Ensured',
#     'State',
#     'Reviewed',
#     'Developed',
#     'State',
#     'State',
#     'Developed',
#     'English',
#     'State'],
#    'ORGANIZATION': ['FLSA',
#     'ADA',
#     'PowerPointSkills',
#     'HR',
#     'HR',
#     'KSAs',
#     'State',
#     'Security',
#     'Radiation',
#     'KSAs',
#     'Cabinet',
#     'Council',
#     'State',
#     'FLSA',
#     'Senior',
#     'State',
#     'HR',
#     'FLSA',
#     'Senior',
#     'CBPs',
#     'DevelopmentSpecialistCompanyName',
#     'ASTD',
#     'EthicalPractice',
#     'University'],
#    'GPE': ['NeoGov']}},
#  {'ID': 32896934,
#   'Category': 'HR',
#   'Skills': [],
#   'Entities': {'PERSON': ['SixSigma',
#     'HighlightsNewEmployee',
#     'KronosTimekeepingSystem',
#     'BenefitsPerformance',
#     'LedgerAccountingDatabase',
#     'CurrentHRClerkCompanyName',
#     'Skills',
#     'SafetyPrograms',
#     'HumanResource',
#     'System',
#     'Degree',
#     'BusinessManagement',
#     'Phoenix',
#     'BusinessManagement',
#     'BusinessManagementBlueRidgeCommunityCollege',
#     'Best',
#     'TycoElectronics',
#     'TycoElectronics',
#     'ProjectTeam',
#     'HumanResourceManagement',
#     'LocalChapter',
#     'HumanResource'],
#    'ORGANIZATION': ['HR',
#     'StateCoordinate',
#     'StateCoordinates',
#     'ITService',
#     'State',
#     'GeneralLedger',
#     'HumanResources',
#     'WorkersCompensation',
#     'State',
#     'Labor',
#     'MRPVacationCalendar',
#     'ContinuousImprovementProgram',
#     'State',
#     'WorkersCompensation',
#     'SHRM',
#     'SHRMProgram',
#     'SHRMBody',
#     'Competency',
#     'SHRM',
#     'HRManagementUniversity',
#     'StateProgram',
#     'HumanResourcesGeneralists',
#     'HR',
#     'SHRMEssentials',
#     'HRManagement',
#     'SHRM',
#     'HR',
#     'HR',
#     'HR',
#     'Associates',
#     'StateBusiness',
#     'SHRM',
#     'MRPCalendar',
#     'Corporate',
#     'SocietyofHumanResourceManagementShenandoahValleySociety',
#     'SHRMSkills',
#     'ContinuousImprovement',
#     'GeneralLedger',
#     'HumanResources',
#     'HR',
#     'MRP'],
#    'GPE': ['Lean', 'Knowledge', 'Safety']}}]

# %%
result_df
# Out:
#          ID Category               Skills  \
# 0  16852973       HR         [Leadership]
# 1  22323967       HR      [Communication]
# 2  33176873       HR  [Excel, Leadership]
# 3  27018550       HR              [Excel]
# 4  17812897       HR              [Excel]
# 5  11592605       HR              [Excel]
# 6  25824789       HR         [Leadership]
# 7  15375009       HR                   []
# 8  11847784       HR              [Excel]
# 9  32896934       HR                   []
#
#                                             Entities
# 0  {'PERSON': ['Client', 'AccomplishmentsMissouri...
# 1  {'PERSON': ['Marketing', 'CurrentHRSpecialist'...
# 2  {'PERSON': ['BenefitAdministrationPolicy', 'Ka...
# 3  {'PERSON': ['Dynamic', 'Solid', 'SkillsType', ...
# 4  {'PERSON': ['SkillHighlightsHR', 'AdvocacyHRPo...
# 5  {'PERSON': ['AdministrativeAssistant', 'Highli...
# 6  {'PERSON': ['State', 'HighlightsUniversity', '...
# 7  {'PERSON': ['DrivenHRManager', 'CreativeBusine...
# 8  {'PERSON': ['Managed', 'Ensured', 'Developed',...
# 9  {'PERSON': ['SixSigma', 'HighlightsNewEmployee...

# %% [markdown]
# Step 6: Visualize Skill Distribution

# %%
from collections import Counter
import matplotlib.pyplot as plt

skills = []
for i in result_df['Skills']:
  skills.extend(i)

skill_freq = Counter(skills)
skill_freq
# Out:
# Counter({'Leadership': 3, 'Communication': 1, 'Excel': 5})

# %%
top = skill_freq.most_common(10)
label, value = zip(*top)

# %%
plt.bar(label, value, color = 'skyblue')
plt.xlabel('Skills')
plt.ylabel('Frequency')
plt.title('Top skills')
plt.show()
